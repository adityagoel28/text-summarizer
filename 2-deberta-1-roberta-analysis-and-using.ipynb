# %% [markdown]
# ## Analysis and using models from three notebooks
#
# **1.** Deberta v3 large (0.8392)
# > [Inference BERT for usPatents](https://www.kaggle.com/code/leehann/inference-bert-for-uspatents)
#
# **2.** Deberta v3 large (0.8338)
# > [PPPM / Deberta-v3-large baseline [inference]](https://www.kaggle.com/code/yasufuminakama/pppm-deberta-v3-large-baseline-inference)
#
# **3.** Roberta-large (0.8143)
# > [PatentPhrase RoBERTa Inference](https://www.kaggle.com/code/santhoshkumarv/patentphrase-roberta-inference-lb-0-814)
#
# #### Please upvote the original notebooks!
#
# ## UPD: I have an error in my code (Version 1)!
#
# Method merge in model 1 shuffled the dataframe.
#
# ```
# test = test.merge(titles, left_on='context', right_on='code')
# ```
#
# So I reseted index, merged, sorted and drop index.
#
# ```
# test.reset_index(inplace=True)
# test = test.merge(titles, left_on='context', right_on='code')
# test.sort_values(by='index', inplace=True)
# test.drop(columns='index', inplace=True)
# ```

# %% [markdown]
# # 1. Import & Def & Set & Load

# %%
import os
import gc
import random

import numpy as np
import pandas as pd

import seaborn as sns

from sklearn.preprocessing import MinMaxScaler

from dataclasses import dataclass

from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

from transformers import AutoModelForSequenceClassification, AutoTokenizer, AutoConfig, AutoModel

import warnings 
warnings.filterwarnings('ignore')

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True    
    torch.backends.cudnn.benchmark = False

    
def inference_fn(test_loader, model, device, is_sigmoid=True):
    preds = []
    model.eval()
    model.to(device)
    tk0 = tqdm(test_loader, total=len(test_loader))
    
    for inputs in tk0:
        for k, v in inputs.items():
            inputs[k] = v.to(device)
            
        with torch.no_grad():
            output = model(inputs)
        
        if is_sigmoid == True:
            preds.append(output.sigmoid().to('cpu').numpy())
        else:
            preds.append(output.to('cpu').numpy())

    return np.concatenate(preds)    
    

def upd_outputs(data, is_trim=False, is_minmax=False, is_reshape=False):
    min_max_scaler = MinMaxScaler()
    
    if is_trim == True:
        data = np.where(data <=0, 0, data)
        data = np.where(data >=1, 1, data)

    if is_minmax ==True:
        data = min_max_scaler.fit_transform(data)
    
    if is_reshape == True:
        data = data.reshape(-1)
        
    return data

# %%
pd.set_option('display.precision', 4)
cm = sns.light_palette('green', as_cmap=True)
props_param = "color:white; font-weight:bold; background-color:green;"

CUSTOM_SEED = 42
CUSTOM_BATCH = 24
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
competition_dir = "../input/us-patent-phrase-to-phrase-matching/"

submission = pd.read_csv(competition_dir+'sample_submission.csv')
test_origin = pd.read_csv(competition_dir+'test.csv')
test_origin.head()
# Out:
#                  id              anchor                         target context
# 0  4112d61851461f60            opc drum  inorganic photoconductor drum     G02
# 1  09e418c93a776564     adjust gas flow              altering gas flow     F23
# 2  36baf228038e314b      lower trunnion                 lower locating     B60
# 3  1f37ead645e7f0c8       cap component                  upper portion     D06
# 4  71a5b6ad068d531f  neural stimulation      artificial neural network     H04

# %% [markdown]
# # 2. Extract predictions
#
# ## 2.1 Deberta v3 large - 1

# %%
def prepare_input(cfg, text):
    inputs = cfg.tokenizer(text,
                           max_length=cfg.max_len,
                           padding="max_length",
                           truncation=True)
    
    for k, v in inputs.items():
        inputs[k] = torch.tensor(v, dtype=torch.long)
        
    return inputs

class TestDataset(Dataset):
    def __init__(self, cfg, df):
        self.cfg = cfg        
        self.text = df['text'].values
        
    def __len__(self):
        return len(self.text)

    def __getitem__(self, item):
        inputs = prepare_input(self.cfg, self.text[item])
        
        return inputs
   
    
class CustomModel(nn.Module):
    def __init__(self, model_path):
        super().__init__()
        
        config = AutoConfig.from_pretrained(model_path)
        config.num_labels = 1
        self.base = AutoModelForSequenceClassification.from_config(config=config)
        dim = config.hidden_size
        self.dropout = nn.Dropout(p=0)
        self.cls = nn.Linear(dim,1)
        
    def forward(self, inputs):
        output = self.base(**inputs)

        return output[0]

# %%
seed_everything(CUSTOM_SEED)

# %%
class CFG:
    model_path='../input/deberta-v3-large/deberta-v3-large'
    batch_size=CUSTOM_BATCH
    num_workers=2
    max_len=130
    trn_fold=[0, 1, 2, 3]

CFG.tokenizer = AutoTokenizer.from_pretrained(CFG.model_path)

context_mapping = torch.load("../input/folds-dump-the-two-paths-fix/cpc_texts.pth")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
test = test_origin.copy()
titles = pd.read_csv('../input/cpc-codes/titles.csv')

test.reset_index(inplace=True)
test = test.merge(titles, left_on='context', right_on='code')
test.sort_values(by='index', inplace=True)
test.drop(columns='index', inplace=True)

test['context_text'] = test['context'].map(context_mapping)
test['text'] = test['anchor'] + '[SEP]' + test['target'] + '[SEP]'  + test['context_text']
test['text'] = test['text'].apply(str.lower)

test.head()
# Out:
#                  id              anchor                         target  \
# 0  4112d61851461f60            opc drum  inorganic photoconductor drum
# 3  09e418c93a776564     adjust gas flow              altering gas flow
# 4  36baf228038e314b      lower trunnion                 lower locating
# 6  1f37ead645e7f0c8       cap component                  upper portion
# 7  71a5b6ad068d531f  neural stimulation      artificial neural network
#
#   context code                                              title section  \
# 0     G02  G02                                             OPTICS       G
# 3     F23  F23         COMBUSTION APPARATUS; COMBUSTION PROCESSES       F
# 4     B60  B60                                VEHICLES IN GENERAL       B
# 6     D06  D06  TREATMENT OF TEXTILES OR THE LIKE; LAUNDERING;...       D
# 7     H04  H04                   ELECTRIC COMMUNICATION TECHNIQUE       H
#
#    class subclass  group  main_group  \
# 0    2.0      NaN    NaN         NaN
# 3   23.0      NaN    NaN         NaN
# 4   60.0      NaN    NaN         NaN
# 6    6.0      NaN    NaN         NaN
# 7    4.0      NaN    NaN         NaN
#
#                                         context_text  \
# 0                                    PHYSICS. OPTICS
# 3  MECHANICAL ENGINEERING; LIGHTING; HEATING; WEA...
# 4  PERFORMING OPERATIONS; TRANSPORTING. VEHICLES ...
# 6  TEXTILES; PAPER. TREATMENT OF TEXTILES OR THE ...
# 7      ELECTRICITY. ELECTRIC COMMUNICATION TECHNIQUE
#
#                                                 text
# 0  opc drum[sep]inorganic photoconductor drum[sep...
# 3  adjust gas flow[sep]altering gas flow[sep]mech...
# 4  lower trunnion[sep]lower locating[sep]performi...
# 6  cap component[sep]upper portion[sep]textiles; ...
# 7  neural stimulation[sep]artificial neural netwo...

# %%
deberta_predicts_1 = []

test_dataset = TestDataset(CFG, test)
test_dataloader = DataLoader(test_dataset,
                             batch_size=CFG.batch_size, shuffle=False,
                             num_workers=CFG.num_workers,
                             pin_memory=True, drop_last=False)

deberta_simple_path = "../input/us-patent-deberta-simple/microsoft_deberta-v3-large"

for fold in CFG.trn_fold:
    fold_path = f"{deberta_simple_path}_best{fold}.pth"
    
    model = CustomModel(CFG.model_path)    
    state = torch.load(fold_path, map_location=torch.device('cpu'))  # DEVICE
    model.load_state_dict(state['model'])
    
    prediction = inference_fn(test_dataloader, model, DEVICE, is_sigmoid=False)
    
    deberta_predicts_1.append(prediction)
    
    del model, state, prediction
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.20it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.19it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.90it/s]

# %%
# -------------- inference_fn([...], is_sigmoid=False)
deberta_predicts_1 = [upd_outputs(x, is_minmax=True, is_reshape=True) for x in deberta_predicts_1]
deberta_predicts_1 = pd.DataFrame(deberta_predicts_1).T

deberta_predicts_1.head(10).style.background_gradient(cmap=cm, axis=1)
# Out:
# <style type="text/css">
# #T_b3a9f_row0_col0, #T_b3a9f_row1_col1, #T_b3a9f_row2_col0, #T_b3a9f_row3_col1, #T_b3a9f_row4_col0, #T_b3a9f_row5_col0, #T_b3a9f_row6_col0, #T_b3a9f_row7_col0, #T_b3a9f_row8_col2, #T_b3a9f_row9_col0, #T_b3a9f_row9_col2, #T_b3a9f_row9_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_b3a9f_row0_col1 {
#   background-color: #e4f0e4;
#   color: #000000;
# }
# #T_b3a9f_row0_col2, #T_b3a9f_row1_col2, #T_b3a9f_row2_col1, #T_b3a9f_row3_col2, #T_b3a9f_row4_col1, #T_b3a9f_row4_col2, #T_b3a9f_row4_col3, #T_b3a9f_row5_col3, #T_b3a9f_row6_col2, #T_b3a9f_row7_col1, #T_b3a9f_row8_col0, #T_b3a9f_row9_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_b3a9f_row0_col3 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_b3a9f_row1_col0 {
#   background-color: #c3e0c3;
#   color: #000000;
# }
# #T_b3a9f_row1_col3 {
#   background-color: #65b265;
#   color: #f1f1f1;
# }
# #T_b3a9f_row2_col2 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_b3a9f_row2_col3 {
#   background-color: #9dcd9d;
#   color: #000000;
# }
# #T_b3a9f_row3_col0 {
#   background-color: #b4d8b4;
#   color: #000000;
# }
# #T_b3a9f_row3_col3 {
#   background-color: #d9ead9;
#   color: #000000;
# }
# #T_b3a9f_row5_col1 {
#   background-color: #83c083;
#   color: #000000;
# }
# #T_b3a9f_row5_col2 {
#   background-color: #d8ead8;
#   color: #000000;
# }
# #T_b3a9f_row6_col1 {
#   background-color: #269226;
#   color: #f1f1f1;
# }
# #T_b3a9f_row6_col3 {
#   background-color: #349a34;
#   color: #f1f1f1;
# }
# #T_b3a9f_row7_col2 {
#   background-color: #0c860c;
#   color: #f1f1f1;
# }
# #T_b3a9f_row7_col3 {
#   background-color: #e2efe2;
#   color: #000000;
# }
# #T_b3a9f_row8_col1 {
#   background-color: #48a348;
#   color: #f1f1f1;
# }
# #T_b3a9f_row8_col3 {
#   background-color: #b1d7b1;
#   color: #000000;
# }
# </style>
# <table id="T_b3a9f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3a9f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3a9f_row0_col0" class="data row0 col0" >0.5510</td>
#       <td id="T_b3a9f_row0_col1" class="data row0 col1" >0.2487</td>
#       <td id="T_b3a9f_row0_col2" class="data row0 col2" >0.2390</td>
#       <td id="T_b3a9f_row0_col3" class="data row0 col3" >0.2670</td>
#     </tr>
#     <tr>
#       <th id="T_b3a9f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3a9f_row1_col0" class="data row1 col0" >0.5259</td>
#       <td id="T_b3a9f_row1_col1" class="data row1 col1" >0.7600</td>
#       <td id="T_b3a9f_row1_col2" class="data row1 col2" >0.4775</td>
#       <td id="T_b3a9f_row1_col3" class="data row1 col3" >0.6383</td>
#     </tr>
#     <tr>
#       <th id="T_b3a9f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3a9f_row2_col0" class="data row2 col0" >0.5402</td>
#       <td id="T_b3a9f_row2_col1" class="data row2 col1" >0.4998</td>
#       <td id="T_b3a9f_row2_col2" class="data row2 col2" >0.5037</td>
#       <td id="T_b3a9f_row2_col3" class="data row2 col3" >0.5131</td>
#     </tr>
#     <tr>
#       <th id="T_b3a9f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3a9f_row3_col0" class="data row3 col0" >0.2696</td>
#       <td id="T_b3a9f_row3_col1" class="data row3 col1" >0.4241</td>
#       <td id="T_b3a9f_row3_col2" class="data row3 col2" >0.2227</td>
#       <td id="T_b3a9f_row3_col3" class="data row3 col3" >0.2377</td>
#     </tr>
#     <tr>
#       <th id="T_b3a9f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3a9f_row4_col0" class="data row4 col0" >0.4514</td>
#       <td id="T_b3a9f_row4_col1" class="data row4 col1" >0.0021</td>
#       <td id="T_b3a9f_row4_col2" class="data row4 col2" >0.0007</td>
#       <td id="T_b3a9f_row4_col3" class="data row4 col3" >0.0009</td>
#     </tr>
#     <tr>
#       <th id="T_b3a9f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b3a9f_row5_col0" class="data row5 col0" >0.5490</td>
#       <td id="T_b3a9f_row5_col1" class="data row5 col1" >0.5047</td>
#       <td id="T_b3a9f_row5_col2" class="data row5 col2" >0.4754</td>
#       <td id="T_b3a9f_row5_col3" class="data row5 col3" >0.4692</td>
#     </tr>
#     <tr>
#       <th id="T_b3a9f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b3a9f_row6_col0" class="data row6 col0" >0.5640</td>
#       <td id="T_b3a9f_row6_col1" class="data row6 col1" >0.5154</td>
#       <td id="T_b3a9f_row6_col2" class="data row6 col2" >0.2642</td>
#       <td id="T_b3a9f_row6_col3" class="data row6 col3" >0.4961</td>
#     </tr>
#     <tr>
#       <th id="T_b3a9f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b3a9f_row7_col0" class="data row7 col0" >0.0071</td>
#       <td id="T_b3a9f_row7_col1" class="data row7 col1" >0.0001</td>
#       <td id="T_b3a9f_row7_col2" class="data row7 col2" >0.0067</td>
#       <td id="T_b3a9f_row7_col3" class="data row7 col3" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_b3a9f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b3a9f_row8_col0" class="data row8 col0" >0.2316</td>
#       <td id="T_b3a9f_row8_col1" class="data row8 col1" >0.2633</td>
#       <td id="T_b3a9f_row8_col2" class="data row8 col2" >0.2773</td>
#       <td id="T_b3a9f_row8_col3" class="data row8 col3" >0.2430</td>
#     </tr>
#     <tr>
#       <th id="T_b3a9f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b3a9f_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_b3a9f_row9_col1" class="data row9 col1" >0.9948</td>
#       <td id="T_b3a9f_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_b3a9f_row9_col3" class="data row9 col3" >1.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
del test, test_dataset
gc.collect()
# Out:
# 46

# %% [markdown]
# ## 2.2 Deberta v3 large - 2

# %%
def prepare_input(cfg, text):
    inputs = cfg.tokenizer(text,
                           add_special_tokens=True,
                           max_length=cfg.max_len,
                           padding="max_length",
                           return_offsets_mapping=False)
    
    for k, v in inputs.items():
        inputs[k] = torch.tensor(v, dtype=torch.long)
        
    return inputs


class TestDataset(Dataset):
    def __init__(self, cfg, df):
        self.cfg = cfg
        self.texts = df['text'].values

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, item):
        inputs = prepare_input(self.cfg, self.texts[item])
        return inputs

    
class CustomModel(nn.Module):
    def __init__(self, cfg, config_path=None, pretrained=False):
        super().__init__()
        self.cfg = cfg
        if config_path is None:
            self.config = AutoConfig.from_pretrained(cfg.model, output_hidden_states=True)
        else:
            self.config = torch.load(config_path)
        if pretrained:
            self.model = AutoModel.from_pretrained(cfg.model, config=self.config)
        else:
            self.model = AutoModel.from_config(self.config)
            
        self.fc_dropout = nn.Dropout(cfg.fc_dropout)
        self.fc = nn.Linear(self.config.hidden_size, self.cfg.target_size)
        self._init_weights(self.fc)
        self.attention = nn.Sequential(
            nn.Linear(self.config.hidden_size, 512),
            nn.Tanh(),
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )
        self._init_weights(self.attention)
        
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)
        
    def feature(self, inputs):
        outputs = self.model(**inputs)
        last_hidden_states = outputs[0]
        weights = self.attention(last_hidden_states)
        feature = torch.sum(weights * last_hidden_states, dim=1)
        
        return feature

    def forward(self, inputs):
        feature = self.feature(inputs)
        output = self.fc(self.fc_dropout(feature))
        
        return output

# %%
seed_everything(CUSTOM_SEED)

# %%
class CFG:
    num_workers=2
    path="../input/pppm-deberta-v3-large-baseline-w-w-b-train/"
    config_path=path+'config.pth'
    model="microsoft/deberta-v3-large"
    batch_size=CUSTOM_BATCH
    fc_dropout=0.2
    target_size=1
    max_len=133
    trn_fold=[0, 1, 2, 3]
    
CFG.tokenizer = AutoTokenizer.from_pretrained(CFG.path+'tokenizer/')

context_mapping = torch.load(CFG.path+"cpc_texts.pth")

# %%
test = test_origin.copy()

test['context_text'] = test['context'].map(context_mapping)
test['text'] = test['anchor'] + '[SEP]' + test['target'] + '[SEP]'  + test['context_text']

test.head()
# Out:
#                  id              anchor                         target  \
# 0  4112d61851461f60            opc drum  inorganic photoconductor drum
# 1  09e418c93a776564     adjust gas flow              altering gas flow
# 2  36baf228038e314b      lower trunnion                 lower locating
# 3  1f37ead645e7f0c8       cap component                  upper portion
# 4  71a5b6ad068d531f  neural stimulation      artificial neural network
#
#   context                                       context_text  \
# 0     G02                                    PHYSICS. OPTICS
# 1     F23  MECHANICAL ENGINEERING; LIGHTING; HEATING; WEA...
# 2     B60  PERFORMING OPERATIONS; TRANSPORTING. VEHICLES ...
# 3     D06  TEXTILES; PAPER. TREATMENT OF TEXTILES OR THE ...
# 4     H04      ELECTRICITY. ELECTRIC COMMUNICATION TECHNIQUE
#
#                                                 text
# 0  opc drum[SEP]inorganic photoconductor drum[SEP...
# 1  adjust gas flow[SEP]altering gas flow[SEP]MECH...
# 2  lower trunnion[SEP]lower locating[SEP]PERFORMI...
# 3  cap component[SEP]upper portion[SEP]TEXTILES; ...
# 4  neural stimulation[SEP]artificial neural netwo...

# %%
deberta_predicts_2 = []

test_dataset = TestDataset(CFG, test)
test_loader = DataLoader(test_dataset,
                         batch_size=CFG.batch_size,
                         shuffle=False,
                         num_workers=CFG.num_workers,
                         pin_memory=True, drop_last=False)

folds_path = CFG.path + f"{CFG.model.replace('/', '-')}"

for fold in CFG.trn_fold:
    fold_path = f"{folds_path}_fold{fold}_best.pth"
    model = CustomModel(CFG, config_path=CFG.config_path, pretrained=False)
    state = torch.load(fold_path, map_location=torch.device('cpu'))  # DEVICE
    model.load_state_dict(state['model'])
    
    prediction = inference_fn(test_loader, model, DEVICE)
    deberta_predicts_2.append(prediction)
    
    del model, state, prediction
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  2.15it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.14it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.14it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.12it/s]

# %%
deberta_predicts_2 = [upd_outputs(x, is_reshape=True) for x in deberta_predicts_2]
deberta_predicts_2 = pd.DataFrame(deberta_predicts_2).T

deberta_predicts_2.head(10).style.background_gradient(cmap=cm, axis=1)
# Out:
# <style type="text/css">
# #T_68839_row0_col0 {
#   background-color: #74b974;
#   color: #f1f1f1;
# }
# #T_68839_row0_col1, #T_68839_row1_col3, #T_68839_row2_col1, #T_68839_row3_col0, #T_68839_row4_col2, #T_68839_row5_col3, #T_68839_row6_col1, #T_68839_row7_col3, #T_68839_row8_col3, #T_68839_row9_col3 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_68839_row0_col2, #T_68839_row1_col1, #T_68839_row2_col0, #T_68839_row3_col1, #T_68839_row4_col0, #T_68839_row5_col2, #T_68839_row6_col3, #T_68839_row7_col2, #T_68839_row8_col0, #T_68839_row9_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_68839_row0_col3, #T_68839_row6_col0 {
#   background-color: #67b267;
#   color: #f1f1f1;
# }
# #T_68839_row1_col0 {
#   background-color: #198c19;
#   color: #f1f1f1;
# }
# #T_68839_row1_col2 {
#   background-color: #75b975;
#   color: #f1f1f1;
# }
# #T_68839_row2_col2 {
#   background-color: #afd6af;
#   color: #000000;
# }
# #T_68839_row2_col3 {
#   background-color: #78bb78;
#   color: #f1f1f1;
# }
# #T_68839_row3_col2 {
#   background-color: #60af60;
#   color: #f1f1f1;
# }
# #T_68839_row3_col3 {
#   background-color: #88c388;
#   color: #000000;
# }
# #T_68839_row4_col1 {
#   background-color: #c0dec0;
#   color: #000000;
# }
# #T_68839_row4_col3 {
#   background-color: #058205;
#   color: #f1f1f1;
# }
# #T_68839_row5_col0 {
#   background-color: #339933;
#   color: #f1f1f1;
# }
# #T_68839_row5_col1 {
#   background-color: #98ca98;
#   color: #000000;
# }
# #T_68839_row6_col2 {
#   background-color: #148a14;
#   color: #f1f1f1;
# }
# #T_68839_row7_col0 {
#   background-color: #d1e6d1;
#   color: #000000;
# }
# #T_68839_row7_col1 {
#   background-color: #6db56d;
#   color: #f1f1f1;
# }
# #T_68839_row8_col1 {
#   background-color: #4ba54b;
#   color: #f1f1f1;
# }
# #T_68839_row8_col2 {
#   background-color: #d0e6d0;
#   color: #000000;
# }
# #T_68839_row9_col1 {
#   background-color: #7cbd7c;
#   color: #000000;
# }
# #T_68839_row9_col2 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_68839_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68839_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68839_row0_col0" class="data row0 col0" >0.5574</td>
#       <td id="T_68839_row0_col1" class="data row0 col1" >0.4311</td>
#       <td id="T_68839_row0_col2" class="data row0 col2" >0.6800</td>
#       <td id="T_68839_row0_col3" class="data row0 col3" >0.5707</td>
#     </tr>
#     <tr>
#       <th id="T_68839_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_68839_row1_col0" class="data row1 col0" >0.7588</td>
#       <td id="T_68839_row1_col1" class="data row1 col1" >0.7719</td>
#       <td id="T_68839_row1_col2" class="data row1 col2" >0.7123</td>
#       <td id="T_68839_row1_col3" class="data row1 col3" >0.6524</td>
#     </tr>
#     <tr>
#       <th id="T_68839_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_68839_row2_col0" class="data row2 col0" >0.5809</td>
#       <td id="T_68839_row2_col1" class="data row2 col1" >0.4549</td>
#       <td id="T_68839_row2_col2" class="data row2 col2" >0.4873</td>
#       <td id="T_68839_row2_col3" class="data row2 col3" >0.5167</td>
#     </tr>
#     <tr>
#       <th id="T_68839_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_68839_row3_col0" class="data row3 col0" >0.2177</td>
#       <td id="T_68839_row3_col1" class="data row3 col1" >0.2776</td>
#       <td id="T_68839_row3_col2" class="data row3 col2" >0.2532</td>
#       <td id="T_68839_row3_col3" class="data row3 col3" >0.2429</td>
#     </tr>
#     <tr>
#       <th id="T_68839_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_68839_row4_col0" class="data row4 col0" >0.0006</td>
#       <td id="T_68839_row4_col1" class="data row4 col1" >0.0003</td>
#       <td id="T_68839_row4_col2" class="data row4 col2" >0.0003</td>
#       <td id="T_68839_row4_col3" class="data row4 col3" >0.0006</td>
#     </tr>
#     <tr>
#       <th id="T_68839_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_68839_row5_col0" class="data row5 col0" >0.5011</td>
#       <td id="T_68839_row5_col1" class="data row5 col1" >0.4691</td>
#       <td id="T_68839_row5_col2" class="data row5 col2" >0.5171</td>
#       <td id="T_68839_row5_col3" class="data row5 col3" >0.4430</td>
#     </tr>
#     <tr>
#       <th id="T_68839_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_68839_row6_col0" class="data row6 col0" >0.4501</td>
#       <td id="T_68839_row6_col1" class="data row6 col1" >0.3675</td>
#       <td id="T_68839_row6_col2" class="data row6 col2" >0.5017</td>
#       <td id="T_68839_row6_col3" class="data row6 col3" >0.5144</td>
#     </tr>
#     <tr>
#       <th id="T_68839_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_68839_row7_col0" class="data row7 col0" >0.0001</td>
#       <td id="T_68839_row7_col1" class="data row7 col1" >0.0002</td>
#       <td id="T_68839_row7_col2" class="data row7 col2" >0.0002</td>
#       <td id="T_68839_row7_col3" class="data row7 col3" >0.0001</td>
#     </tr>
#     <tr>
#       <th id="T_68839_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_68839_row8_col0" class="data row8 col0" >0.3764</td>
#       <td id="T_68839_row8_col1" class="data row8 col1" >0.3466</td>
#       <td id="T_68839_row8_col2" class="data row8 col2" >0.2944</td>
#       <td id="T_68839_row8_col3" class="data row8 col3" >0.2838</td>
#     </tr>
#     <tr>
#       <th id="T_68839_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_68839_row9_col0" class="data row9 col0" >0.9994</td>
#       <td id="T_68839_row9_col1" class="data row9 col1" >0.9990</td>
#       <td id="T_68839_row9_col2" class="data row9 col2" >0.9991</td>
#       <td id="T_68839_row9_col3" class="data row9 col3" >0.9986</td>
#     </tr>
#   </tbody>
# </table>

# %%
del test, test_dataset
gc.collect()
# Out:
# 46

# %% [markdown]
# ## 2.3. Roberta-large

# %%
def prepare_input(cfg, text, target):
    inputs = cfg.tokenizer(text, target,
                           padding="max_length",
                           max_length=cfg.max_len,
                           truncation=True)

    for k, v in inputs.items():
        inputs[k] = torch.tensor(v, dtype=torch.long)
        
    return inputs


class TestDataset(Dataset):
    def __init__(self, cfg, df):
        self.cfg = cfg
        self.texts = df['text'].values
        self.target = df['target'].values
        
    def __len__(self):
        return len(self.texts)

    def __getitem__(self, item):
        text = self.texts[item]
        target = self.target[item]
        
        inputs = prepare_input(self.cfg, text, target)
        
        return inputs

    
class CustomModel(nn.Module):
    def __init__(self):
        super(CustomModel, self).__init__()
        hidden_dropout_prob: float = 0.1
        layer_norm_eps: float = 1e-7

        config = AutoConfig.from_pretrained(CFG.config_path)

        config.update({"output_hidden_states": True,
                       "hidden_dropout_prob": hidden_dropout_prob,
                       "layer_norm_eps": layer_norm_eps,
                       "add_pooling_layer": False})
        
        self.transformer = AutoModel.from_pretrained(CFG.config_path, config=config)
        self.dropout = nn.Dropout(config.hidden_dropout_prob)
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.2)
        self.dropout3 = nn.Dropout(0.3)
        self.dropout4 = nn.Dropout(0.4)
        self.dropout5 = nn.Dropout(0.5)
        self.output = nn.Linear(config.hidden_size, CFG.num_targets)
        
    def forward(self, inputs):
        transformer_out = self.transformer(**inputs)
        last_hidden_states = transformer_out[0]
        last_hidden_states = self.dropout(torch.mean(last_hidden_states, 1))
        logits1 = self.output(self.dropout1(last_hidden_states))
        logits2 = self.output(self.dropout2(last_hidden_states))
        logits3 = self.output(self.dropout3(last_hidden_states))
        logits4 = self.output(self.dropout4(last_hidden_states))
        logits5 = self.output(self.dropout5(last_hidden_states))
        logits = (logits1 + logits2 + logits3 + logits4 + logits5) / 5
        
        return logits

# %%
seed_everything(CUSTOM_SEED)

# %%
@dataclass(frozen=True)
class CFG:
    num_workers=2
    config_path='../input/robertalarge'
    model_path='../input/phrase-matching-roberta-training-pytorch-wandb'
    model_name='roberta-large'
    batch_size=CUSTOM_BATCH
    max_len=128
    num_targets=1
    trn_fold=[0, 1, 2, 3, 4]
    tokenizer=AutoTokenizer.from_pretrained('../input/robertalarge')

context_mapping = {
        "A": "Human Necessities",
        "B": "Operations and Transport",
        "C": "Chemistry and Metallurgy",
        "D": "Textiles",
        "E": "Fixed Constructions",
        "F": "Mechanical Engineering",
        "G": "Physics",
        "H": "Electricity",
        "Y": "Emerging Cross-Sectional Technologies",
}

# %%
test = test_origin.copy()

test['context_text'] = test['context'].str.slice(stop=1).map(context_mapping)
test['text'] = test['context_text'] + ' ' + test['anchor']

# %%
test.head()
# Out:
#                  id              anchor                         target  \
# 0  4112d61851461f60            opc drum  inorganic photoconductor drum
# 1  09e418c93a776564     adjust gas flow              altering gas flow
# 2  36baf228038e314b      lower trunnion                 lower locating
# 3  1f37ead645e7f0c8       cap component                  upper portion
# 4  71a5b6ad068d531f  neural stimulation      artificial neural network
#
#   context              context_text                                     text
# 0     G02                   Physics                         Physics opc drum
# 1     F23    Mechanical Engineering   Mechanical Engineering adjust gas flow
# 2     B60  Operations and Transport  Operations and Transport lower trunnion
# 3     D06                  Textiles                   Textiles cap component
# 4     H04               Electricity           Electricity neural stimulation

# %%
roberta_predicts = []

test_dataset = TestDataset(CFG, test)
test_loader = DataLoader(test_dataset,
                         batch_size=CFG.batch_size,
                         shuffle=False,
                         num_workers=CFG.num_workers,
                         pin_memory=True, drop_last=False)

folds_path = CFG.model_path + f"/{CFG.model_name.replace('-','_')}"

for fold in CFG.trn_fold:
    fold_path = f"{folds_path}_patent_model_{fold}.pth"
    
    model = CustomModel()
    state = torch.load(fold_path, map_location=torch.device('cpu'))  # DEVICE
    model.load_state_dict(state)

    prediction = inference_fn(test_loader, model, DEVICE)
    roberta_predicts.append(prediction)
    
    del model, state, prediction
    torch.cuda.empty_cache()    
    gc.collect()
# Out:
# Some weights of the model checkpoint at ../input/robertalarge were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|██████████| 2/2 [00:00<00:00,  2.50it/s]
# Some weights of the model checkpoint at ../input/robertalarge were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|██████████| 2/2 [00:00<00:00,  2.72it/s]
# Some weights of the model checkpoint at ../input/robertalarge were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|██████████| 2/2 [00:00<00:00,  2.61it/s]
# Some weights of the model checkpoint at ../input/robertalarge were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|██████████| 2/2 [00:00<00:00,  2.68it/s]
# Some weights of the model checkpoint at ../input/robertalarge were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|██████████| 2/2 [00:00<00:00,  2.54it/s]

# %%
roberta_predicts = [upd_outputs(x, is_reshape=True) for x in roberta_predicts]
roberta_predicts = pd.DataFrame(roberta_predicts).T

roberta_predicts.head(10).style.background_gradient(cmap=cm, axis=1)
# Out:
# <style type="text/css">
# #T_2bc65_row0_col0 {
#   background-color: #e2efe2;
#   color: #000000;
# }
# #T_2bc65_row0_col1, #T_2bc65_row0_col3, #T_2bc65_row1_col4, #T_2bc65_row2_col1, #T_2bc65_row3_col3, #T_2bc65_row4_col2, #T_2bc65_row4_col3, #T_2bc65_row5_col4, #T_2bc65_row6_col1, #T_2bc65_row7_col2, #T_2bc65_row8_col0, #T_2bc65_row9_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_2bc65_row0_col2 {
#   background-color: #c0dec0;
#   color: #000000;
# }
# #T_2bc65_row0_col4, #T_2bc65_row1_col1, #T_2bc65_row2_col4, #T_2bc65_row3_col2, #T_2bc65_row4_col0, #T_2bc65_row5_col3, #T_2bc65_row6_col4, #T_2bc65_row7_col1, #T_2bc65_row8_col1, #T_2bc65_row9_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_2bc65_row1_col0 {
#   background-color: #65b265;
#   color: #f1f1f1;
# }
# #T_2bc65_row1_col2 {
#   background-color: #a6d2a6;
#   color: #000000;
# }
# #T_2bc65_row1_col3 {
#   background-color: #8fc68f;
#   color: #000000;
# }
# #T_2bc65_row2_col0 {
#   background-color: #389b38;
#   color: #f1f1f1;
# }
# #T_2bc65_row2_col2 {
#   background-color: #379b37;
#   color: #f1f1f1;
# }
# #T_2bc65_row2_col3 {
#   background-color: #44a144;
#   color: #f1f1f1;
# }
# #T_2bc65_row3_col0 {
#   background-color: #92c892;
#   color: #000000;
# }
# #T_2bc65_row3_col1 {
#   background-color: #3d9e3d;
#   color: #f1f1f1;
# }
# #T_2bc65_row3_col4 {
#   background-color: #93c893;
#   color: #000000;
# }
# #T_2bc65_row4_col1 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_2bc65_row4_col4 {
#   background-color: #e0eee0;
#   color: #000000;
# }
# #T_2bc65_row5_col0 {
#   background-color: #48a348;
#   color: #f1f1f1;
# }
# #T_2bc65_row5_col1 {
#   background-color: #b8dab8;
#   color: #000000;
# }
# #T_2bc65_row5_col2 {
#   background-color: #95c995;
#   color: #000000;
# }
# #T_2bc65_row6_col0 {
#   background-color: #cee5ce;
#   color: #000000;
# }
# #T_2bc65_row6_col2 {
#   background-color: #64b164;
#   color: #f1f1f1;
# }
# #T_2bc65_row6_col3 {
#   background-color: #b0d6b0;
#   color: #000000;
# }
# #T_2bc65_row7_col0 {
#   background-color: #c9e3c9;
#   color: #000000;
# }
# #T_2bc65_row7_col3 {
#   background-color: #63b163;
#   color: #f1f1f1;
# }
# #T_2bc65_row7_col4 {
#   background-color: #8ec58e;
#   color: #000000;
# }
# #T_2bc65_row8_col2 {
#   background-color: #aed5ae;
#   color: #000000;
# }
# #T_2bc65_row8_col3 {
#   background-color: #a8d2a8;
#   color: #000000;
# }
# #T_2bc65_row8_col4 {
#   background-color: #88c388;
#   color: #000000;
# }
# #T_2bc65_row9_col0 {
#   background-color: #99cb99;
#   color: #000000;
# }
# #T_2bc65_row9_col2 {
#   background-color: #c9e2c8;
#   color: #000000;
# }
# #T_2bc65_row9_col4 {
#   background-color: #b7dab7;
#   color: #000000;
# }
# </style>
# <table id="T_2bc65_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bc65_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2bc65_row0_col0" class="data row0 col0" >0.5383</td>
#       <td id="T_2bc65_row0_col1" class="data row0 col1" >0.5301</td>
#       <td id="T_2bc65_row0_col2" class="data row0 col2" >0.5678</td>
#       <td id="T_2bc65_row0_col3" class="data row0 col3" >0.5301</td>
#       <td id="T_2bc65_row0_col4" class="data row0 col4" >0.7397</td>
#     </tr>
#     <tr>
#       <th id="T_2bc65_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2bc65_row1_col0" class="data row1 col0" >0.7630</td>
#       <td id="T_2bc65_row1_col1" class="data row1 col1" >0.8501</td>
#       <td id="T_2bc65_row1_col2" class="data row1 col2" >0.7076</td>
#       <td id="T_2bc65_row1_col3" class="data row1 col3" >0.7278</td>
#       <td id="T_2bc65_row1_col4" class="data row1 col4" >0.6489</td>
#     </tr>
#     <tr>
#       <th id="T_2bc65_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2bc65_row2_col0" class="data row2 col0" >0.4582</td>
#       <td id="T_2bc65_row2_col1" class="data row2 col1" >0.1184</td>
#       <td id="T_2bc65_row2_col2" class="data row2 col2" >0.4592</td>
#       <td id="T_2bc65_row2_col3" class="data row2 col3" >0.4341</td>
#       <td id="T_2bc65_row2_col4" class="data row2 col4" >0.5646</td>
#     </tr>
#     <tr>
#       <th id="T_2bc65_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2bc65_row3_col0" class="data row3 col0" >0.2830</td>
#       <td id="T_2bc65_row3_col1" class="data row3 col1" >0.2947</td>
#       <td id="T_2bc65_row3_col2" class="data row3 col2" >0.3029</td>
#       <td id="T_2bc65_row3_col3" class="data row3 col3" >0.2711</td>
#       <td id="T_2bc65_row3_col4" class="data row3 col4" >0.2829</td>
#     </tr>
#     <tr>
#       <th id="T_2bc65_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2bc65_row4_col0" class="data row4 col0" >0.1210</td>
#       <td id="T_2bc65_row4_col1" class="data row4 col1" >0.0044</td>
#       <td id="T_2bc65_row4_col2" class="data row4 col2" >0.0006</td>
#       <td id="T_2bc65_row4_col3" class="data row4 col3" >0.0010</td>
#       <td id="T_2bc65_row4_col4" class="data row4 col4" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_2bc65_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2bc65_row5_col0" class="data row5 col0" >0.5122</td>
#       <td id="T_2bc65_row5_col1" class="data row5 col1" >0.4771</td>
#       <td id="T_2bc65_row5_col2" class="data row5 col2" >0.4879</td>
#       <td id="T_2bc65_row5_col3" class="data row5 col3" >0.5350</td>
#       <td id="T_2bc65_row5_col4" class="data row5 col4" >0.4610</td>
#     </tr>
#     <tr>
#       <th id="T_2bc65_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2bc65_row6_col0" class="data row6 col0" >0.4674</td>
#       <td id="T_2bc65_row6_col1" class="data row6 col1" >0.4594</td>
#       <td id="T_2bc65_row6_col2" class="data row6 col2" >0.4970</td>
#       <td id="T_2bc65_row6_col3" class="data row6 col3" >0.4760</td>
#       <td id="T_2bc65_row6_col4" class="data row6 col4" >0.5252</td>
#     </tr>
#     <tr>
#       <th id="T_2bc65_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2bc65_row7_col0" class="data row7 col0" >0.0003</td>
#       <td id="T_2bc65_row7_col1" class="data row7 col1" >0.0008</td>
#       <td id="T_2bc65_row7_col2" class="data row7 col2" >0.0002</td>
#       <td id="T_2bc65_row7_col3" class="data row7 col3" >0.0005</td>
#       <td id="T_2bc65_row7_col4" class="data row7 col4" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_2bc65_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2bc65_row8_col0" class="data row8 col0" >0.2505</td>
#       <td id="T_2bc65_row8_col1" class="data row8 col1" >0.3610</td>
#       <td id="T_2bc65_row8_col2" class="data row8 col2" >0.2793</td>
#       <td id="T_2bc65_row8_col3" class="data row8 col3" >0.2819</td>
#       <td id="T_2bc65_row8_col4" class="data row8 col4" >0.2967</td>
#     </tr>
#     <tr>
#       <th id="T_2bc65_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2bc65_row9_col0" class="data row9 col0" >0.9975</td>
#       <td id="T_2bc65_row9_col1" class="data row9 col1" >0.9969</td>
#       <td id="T_2bc65_row9_col2" class="data row9 col2" >0.9971</td>
#       <td id="T_2bc65_row9_col3" class="data row9 col3" >0.9987</td>
#       <td id="T_2bc65_row9_col4" class="data row9 col4" >0.9973</td>
#     </tr>
#   </tbody>
# </table>

# %%
del test, test_dataset
gc.collect()
# Out:
# 67

# %% [markdown]
# # 3. Comparison / Ensemble

# %%
all_predictions = pd.concat(
    [deberta_predicts_1, deberta_predicts_2, roberta_predicts],
    keys=['deberta 1', 'deberta 2', 'roberta'],
    axis=1
)

all_predictions.head(10) \
    .assign(mean=lambda x: x.mean(axis=1)) \
        .style.background_gradient(cmap=cm, axis=1)
# Out:
# <style type="text/css">
# #T_c63a3_row0_col0 {
#   background-color: #58ab58;
#   color: #f1f1f1;
# }
# #T_c63a3_row0_col1, #T_c63a3_row7_col8 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# #T_c63a3_row0_col2, #T_c63a3_row1_col2, #T_c63a3_row2_col9, #T_c63a3_row3_col4, #T_c63a3_row4_col2, #T_c63a3_row4_col3, #T_c63a3_row4_col4, #T_c63a3_row4_col5, #T_c63a3_row4_col6, #T_c63a3_row4_col7, #T_c63a3_row4_col10, #T_c63a3_row4_col11, #T_c63a3_row5_col7, #T_c63a3_row6_col2, #T_c63a3_row7_col1, #T_c63a3_row7_col4, #T_c63a3_row7_col7, #T_c63a3_row8_col0, #T_c63a3_row9_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_c63a3_row0_col3 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_c63a3_row0_col4, #T_c63a3_row1_col6 {
#   background-color: #56aa56;
#   color: #f1f1f1;
# }
# #T_c63a3_row0_col5 {
#   background-color: #90c790;
#   color: #000000;
# }
# #T_c63a3_row0_col6 {
#   background-color: #1c8e1c;
#   color: #f1f1f1;
# }
# #T_c63a3_row0_col7 {
#   background-color: #4fa74f;
#   color: #f1f1f1;
# }
# #T_c63a3_row0_col8 {
#   background-color: #5fae5f;
#   color: #f1f1f1;
# }
# #T_c63a3_row0_col9, #T_c63a3_row0_col11, #T_c63a3_row5_col1 {
#   background-color: #62b062;
#   color: #f1f1f1;
# }
# #T_c63a3_row0_col10 {
#   background-color: #50a750;
#   color: #f1f1f1;
# }
# #T_c63a3_row0_col12, #T_c63a3_row1_col9, #T_c63a3_row2_col4, #T_c63a3_row3_col1, #T_c63a3_row4_col0, #T_c63a3_row5_col0, #T_c63a3_row6_col0, #T_c63a3_row7_col0, #T_c63a3_row8_col4, #T_c63a3_row9_col0, #T_c63a3_row9_col2, #T_c63a3_row9_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_c63a3_row0_col13 {
#   background-color: #72b872;
#   color: #f1f1f1;
# }
# #T_c63a3_row1_col0, #T_c63a3_row8_col8 {
#   background-color: #cce4cc;
#   color: #000000;
# }
# #T_c63a3_row1_col1 {
#   background-color: #389b38;
#   color: #f1f1f1;
# }
# #T_c63a3_row1_col3 {
#   background-color: #85c185;
#   color: #000000;
# }
# #T_c63a3_row1_col4 {
#   background-color: #399c39;
#   color: #f1f1f1;
# }
# #T_c63a3_row1_col5, #T_c63a3_row6_col6 {
#   background-color: #319831;
#   color: #f1f1f1;
# }
# #T_c63a3_row1_col7 {
#   background-color: #7cbd7c;
#   color: #000000;
# }
# #T_c63a3_row1_col8 {
#   background-color: #369b36;
#   color: #f1f1f1;
# }
# #T_c63a3_row1_col10, #T_c63a3_row6_col4 {
#   background-color: #59ac59;
#   color: #f1f1f1;
# }
# #T_c63a3_row1_col11 {
#   background-color: #4da64d;
#   color: #f1f1f1;
# }
# #T_c63a3_row1_col12 {
#   background-color: #7fbe7f;
#   color: #000000;
# }
# #T_c63a3_row1_col13 {
#   background-color: #63b163;
#   color: #f1f1f1;
# }
# #T_c63a3_row2_col0 {
#   background-color: #148a14;
#   color: #f1f1f1;
# }
# #T_c63a3_row2_col1 {
#   background-color: #289428;
#   color: #f1f1f1;
# }
# #T_c63a3_row2_col2, #T_c63a3_row6_col7 {
#   background-color: #279327;
#   color: #f1f1f1;
# }
# #T_c63a3_row2_col3 {
#   background-color: #229122;
#   color: #f1f1f1;
# }
# #T_c63a3_row2_col5 {
#   background-color: #3f9f3f;
#   color: #f1f1f1;
# }
# #T_c63a3_row2_col6 {
#   background-color: #2f972f;
#   color: #f1f1f1;
# }
# #T_c63a3_row2_col7 {
#   background-color: #209020;
#   color: #f1f1f1;
# }
# #T_c63a3_row2_col8, #T_c63a3_row2_col10, #T_c63a3_row9_col7 {
#   background-color: #3e9e3e;
#   color: #f1f1f1;
# }
# #T_c63a3_row2_col11, #T_c63a3_row6_col13, #T_c63a3_row9_col13 {
#   background-color: #4ba54a;
#   color: #f1f1f1;
# }
# #T_c63a3_row2_col12 {
#   background-color: #088408;
#   color: #f1f1f1;
# }
# #T_c63a3_row2_col13 {
#   background-color: #379b37;
#   color: #f1f1f1;
# }
# #T_c63a3_row3_col0 {
#   background-color: #b0d6b0;
#   color: #000000;
# }
# #T_c63a3_row3_col2 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_c63a3_row3_col3, #T_c63a3_row4_col13, #T_c63a3_row7_col9 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_c63a3_row3_col5 {
#   background-color: #a6d2a6;
#   color: #000000;
# }
# #T_c63a3_row3_col6 {
#   background-color: #c2dfc2;
#   color: #000000;
# }
# #T_c63a3_row3_col7 {
#   background-color: #cee5ce;
#   color: #000000;
# }
# #T_c63a3_row3_col8 {
#   background-color: #a0cea0;
#   color: #000000;
# }
# #T_c63a3_row3_col9 {
#   background-color: #93c893;
#   color: #000000;
# }
# #T_c63a3_row3_col10, #T_c63a3_row8_col13 {
#   background-color: #8ac48a;
#   color: #000000;
# }
# #T_c63a3_row3_col11 {
#   background-color: #aed5ae;
#   color: #000000;
# }
# #T_c63a3_row3_col12, #T_c63a3_row8_col2 {
#   background-color: #a1cfa1;
#   color: #000000;
# }
# #T_c63a3_row3_col13 {
#   background-color: #a9d3a9;
#   color: #000000;
# }
# #T_c63a3_row4_col1, #T_c63a3_row7_col5, #T_c63a3_row7_col10 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_c63a3_row4_col8 {
#   background-color: #acd4ac;
#   color: #000000;
# }
# #T_c63a3_row4_col9, #T_c63a3_row7_col6 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_c63a3_row4_col12 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_c63a3_row5_col2 {
#   background-color: #a3d0a3;
#   color: #000000;
# }
# #T_c63a3_row5_col3, #T_c63a3_row5_col5 {
#   background-color: #b1d7b1;
#   color: #000000;
# }
# #T_c63a3_row5_col4 {
#   background-color: #6ab46a;
#   color: #f1f1f1;
# }
# #T_c63a3_row5_col6 {
#   background-color: #47a347;
#   color: #f1f1f1;
# }
# #T_c63a3_row5_col8 {
#   background-color: #51a851;
#   color: #f1f1f1;
# }
# #T_c63a3_row5_col9 {
#   background-color: #9fce9f;
#   color: #000000;
# }
# #T_c63a3_row5_col10 {
#   background-color: #87c287;
#   color: #000000;
# }
# #T_c63a3_row5_col11, #T_c63a3_row6_col12 {
#   background-color: #1e8f1e;
#   color: #f1f1f1;
# }
# #T_c63a3_row5_col12, #T_c63a3_row7_col13 {
#   background-color: #c3e0c3;
#   color: #000000;
# }
# #T_c63a3_row5_col13 {
#   background-color: #7dbd7d;
#   color: #000000;
# }
# #T_c63a3_row6_col1 {
#   background-color: #269226;
#   color: #f1f1f1;
# }
# #T_c63a3_row6_col3, #T_c63a3_row6_col10 {
#   background-color: #349a34;
#   color: #f1f1f1;
# }
# #T_c63a3_row6_col5, #T_c63a3_row8_col11 {
#   background-color: #9acb9a;
#   color: #000000;
# }
# #T_c63a3_row6_col8 {
#   background-color: #4ba54b;
#   color: #f1f1f1;
# }
# #T_c63a3_row6_col9 {
#   background-color: #52a852;
#   color: #f1f1f1;
# }
# #T_c63a3_row6_col11 {
#   background-color: #45a245;
#   color: #f1f1f1;
# }
# #T_c63a3_row7_col2 {
#   background-color: #0c860c;
#   color: #f1f1f1;
# }
# #T_c63a3_row7_col3, #T_c63a3_row7_col12 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_c63a3_row7_col11 {
#   background-color: #ddecdd;
#   color: #000000;
# }
# #T_c63a3_row8_col1 {
#   background-color: #b7dab7;
#   color: #000000;
# }
# #T_c63a3_row8_col3 {
#   background-color: #d8ead8;
#   color: #000000;
# }
# #T_c63a3_row8_col5 {
#   background-color: #309730;
#   color: #f1f1f1;
# }
# #T_c63a3_row8_col6 {
#   background-color: #84c184;
#   color: #000000;
# }
# #T_c63a3_row8_col7 {
#   background-color: #96c996;
#   color: #000000;
# }
# #T_c63a3_row8_col9 {
#   background-color: #198c19;
#   color: #f1f1f1;
# }
# #T_c63a3_row8_col10 {
#   background-color: #9dcd9d;
#   color: #000000;
# }
# #T_c63a3_row8_col12, #T_c63a3_row9_col10 {
#   background-color: #81bf81;
#   color: #000000;
# }
# #T_c63a3_row9_col4 {
#   background-color: #1d8e1d;
#   color: #f1f1f1;
# }
# #T_c63a3_row9_col5 {
#   background-color: #2e972e;
#   color: #f1f1f1;
# }
# #T_c63a3_row9_col6 {
#   background-color: #289328;
#   color: #f1f1f1;
# }
# #T_c63a3_row9_col8 {
#   background-color: #6fb76f;
#   color: #f1f1f1;
# }
# #T_c63a3_row9_col9 {
#   background-color: #8dc58d;
#   color: #000000;
# }
# #T_c63a3_row9_col11 {
#   background-color: #3a9c3a;
#   color: #f1f1f1;
# }
# #T_c63a3_row9_col12 {
#   background-color: #7abc7a;
#   color: #000000;
# }
# </style>
# <table id="T_c63a3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="4">deberta 1</th>
#       <th class="col_heading level0 col4" colspan="4">deberta 2</th>
#       <th class="col_heading level0 col8" colspan="5">roberta</th>
#       <th class="col_heading level0 col13" >mean</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >0</th>
#       <th class="col_heading level1 col1" >1</th>
#       <th class="col_heading level1 col2" >2</th>
#       <th class="col_heading level1 col3" >3</th>
#       <th class="col_heading level1 col4" >0</th>
#       <th class="col_heading level1 col5" >1</th>
#       <th class="col_heading level1 col6" >2</th>
#       <th class="col_heading level1 col7" >3</th>
#       <th class="col_heading level1 col8" >0</th>
#       <th class="col

# %%
all_mean = pd.DataFrame({
    'deberta 1': deberta_predicts_1.mean(axis=1),
    'deberta 2': deberta_predicts_2.mean(axis=1),
    'roberta': roberta_predicts.mean(axis=1)
})

all_mean.head(10) \
    .assign(mean=lambda x: x.mean(axis=1)) \
        .style.highlight_max(axis=1, props=props_param)
# Out:
# <style type="text/css">
# #T_ae18f_row0_col2, #T_ae18f_row1_col2, #T_ae18f_row2_col0, #T_ae18f_row3_col0, #T_ae18f_row4_col0, #T_ae18f_row5_col0, #T_ae18f_row6_col2, #T_ae18f_row7_col0, #T_ae18f_row8_col1, #T_ae18f_row9_col1 {
#   color: white;
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_ae18f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >deberta 1</th>
#       <th class="col_heading level0 col1" >deberta 2</th>
#       <th class="col_heading level0 col2" >roberta</th>
#       <th class="col_heading level0 col3" >mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae18f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae18f_row0_col0" class="data row0 col0" >0.3264</td>
#       <td id="T_ae18f_row0_col1" class="data row0 col1" >0.5598</td>
#       <td id="T_ae18f_row0_col2" class="data row0 col2" >0.5812</td>
#       <td id="T_ae18f_row0_col3" class="data row0 col3" >0.4891</td>
#     </tr>
#     <tr>
#       <th id="T_ae18f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae18f_row1_col0" class="data row1 col0" >0.6004</td>
#       <td id="T_ae18f_row1_col1" class="data row1 col1" >0.7238</td>
#       <td id="T_ae18f_row1_col2" class="data row1 col2" >0.7395</td>
#       <td id="T_ae18f_row1_col3" class="data row1 col3" >0.6879</td>
#     </tr>
#     <tr>
#       <th id="T_ae18f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ae18f_row2_col0" class="data row2 col0" >0.5142</td>
#       <td id="T_ae18f_row2_col1" class="data row2 col1" >0.5100</td>
#       <td id="T_ae18f_row2_col2" class="data row2 col2" >0.4069</td>
#       <td id="T_ae18f_row2_col3" class="data row2 col3" >0.4770</td>
#     </tr>
#     <tr>
#       <th id="T_ae18f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ae18f_row3_col0" class="data row3 col0" >0.2885</td>
#       <td id="T_ae18f_row3_col1" class="data row3 col1" >0.2478</td>
#       <td id="T_ae18f_row3_col2" class="data row3 col2" >0.2869</td>
#       <td id="T_ae18f_row3_col3" class="data row3 col3" >0.2744</td>
#     </tr>
#     <tr>
#       <th id="T_ae18f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ae18f_row4_col0" class="data row4 col0" >0.1138</td>
#       <td id="T_ae18f_row4_col1" class="data row4 col1" >0.0005</td>
#       <td id="T_ae18f_row4_col2" class="data row4 col2" >0.0266</td>
#       <td id="T_ae18f_row4_col3" class="data row4 col3" >0.0469</td>
#     </tr>
#     <tr>
#       <th id="T_ae18f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ae18f_row5_col0" class="data row5 col0" >0.4996</td>
#       <td id="T_ae18f_row5_col1" class="data row5 col1" >0.4826</td>
#       <td id="T_ae18f_row5_col2" class="data row5 col2" >0.4946</td>
#       <td id="T_ae18f_row5_col3" class="data row5 col3" >0.4923</td>
#     </tr>
#     <tr>
#       <th id="T_ae18f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ae18f_row6_col0" class="data row6 col0" >0.4599</td>
#       <td id="T_ae18f_row6_col1" class="data row6 col1" >0.4584</td>
#       <td id="T_ae18f_row6_col2" class="data row6 col2" >0.4850</td>
#       <td id="T_ae18f_row6_col3" class="data row6 col3" >0.4678</td>
#     </tr>
#     <tr>
#       <th id="T_ae18f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ae18f_row7_col0" class="data row7 col0" >0.0036</td>
#       <td id="T_ae18f_row7_col1" class="data row7 col1" >0.0001</td>
#       <td id="T_ae18f_row7_col2" class="data row7 col2" >0.0004</td>
#       <td id="T_ae18f_row7_col3" class="data row7 col3" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_ae18f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ae18f_row8_col0" class="data row8 col0" >0.2538</td>
#       <td id="T_ae18f_row8_col1" class="data row8 col1" >0.3253</td>
#       <td id="T_ae18f_row8_col2" class="data row8 col2" >0.2939</td>
#       <td id="T_ae18f_row8_col3" class="data row8 col3" >0.2910</td>
#     </tr>
#     <tr>
#       <th id="T_ae18f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ae18f_row9_col0" class="data row9 col0" >0.9987</td>
#       <td id="T_ae18f_row9_col1" class="data row9 col1" >0.9990</td>
#       <td id="T_ae18f_row9_col2" class="data row9 col2" >0.9975</td>
#       <td id="T_ae18f_row9_col3" class="data row9 col3" >0.9984</td>
#     </tr>
#   </tbody>
# </table>

# %%
# === N1 ===
# weights_ = [0.33, 0.33, 0.33]
# final_predictions = all_mean.mul(weights_).sum(axis=1)

# === N2 ===
# final_predictions = all_mean.median(axis=1)
final_predictions = all_mean.mean(axis=1)

# === N3 ===
# final_predictions = all_predictions.mean(axis=1)

# === N4 ===
# combs = pd.DataFrame({
#     'deberta_1': deberta_predicts_1.mean(axis=1),
#     'deb_2+rob': (deberta_predicts_2.mean(axis=1) * 0.666) \
#                     + (roberta_predicts.mean(axis=1) * 0.333)
# })
# display(combs.head())
# final_predictions = combs.median(axis=1)
# final_predictions = combs.mean(axis=1)

final_predictions.head()
# Out:
# 0    0.4891
# 1    0.6879
# 2    0.4770
# 3    0.2744
# 4    0.0469
# dtype: float32

# %% [markdown]
# # 4. Submission

# %%
submission = pd.DataFrame({
    'id': test_origin['id'],
    'score': final_predictions,
})

submission.head(14)
# Out:
#                   id   score
# 0   4112d61851461f60  0.4891
# 1   09e418c93a776564  0.6879
# 2   36baf228038e314b  0.4770
# 3   1f37ead645e7f0c8  0.2744
# 4   71a5b6ad068d531f  0.0469
# 5   474c874d0c07bd21  0.4923
# 6   442c114ed5c4e3c9  0.4678
# 7   b8ae62ea5e1d8bdb  0.0014
# 8   faaddaf8fcba8a3f  0.2910
# 9   ae0262c02566d2ce  0.9984
# 10  a8808e31641e856d  0.2307
# 11  16ae4b99d3601e60  0.2751
# 12  25c555ca3d5a2092  0.7460
# 13  5203a36c501f1b7c  0.8377

# %%
# ===================  Baseline
# 0  4112d61851461f60  0.56127
# 1  09e418c93a776564  0.72176
# 2  36baf228038e314b  0.47086
# 3  1f37ead645e7f0c8  0.25826
# 4  71a5b6ad068d531f  0.00908
# 5  474c874d0c07bd21  0.48173

# %%
submission.to_csv('submission.csv', index=False)
